# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/product_sales_dataset_final.csv')

# %%
df.head()
# Out:
#    Order_ID Order_Date     Customer_Name          City        State  Region  \
# 0         1   08-23-23      Bianca Brown       Jackson  Mississippi   South
# 1         2   12-20-24     Jared Edwards  Grand Rapids     Michigan  Centre
# 2         3   01-29-24      Susan Valdez   Minneapolis    Minnesota  Centre
# 3         4   11-29-24     Tina Williams   Tallahassee      Florida   South
# 4         5   09-21-23  Catherine Gordon     Baltimore     Maryland    East
#
#          Country            Category       Sub_Category      Product_Name  \
# 0  United States         Accessories  Small Electronics        Phone Case
# 1  United States         Accessories  Small Electronics    Charging Cable
# 2  United States  Clothing & Apparel         Sportswear  Nike Air Force 1
# 3  United States  Clothing & Apparel         Sportswear  Adidas Tracksuit
# 4  United States         Accessories               Bags          Backpack
#
#    Quantity   Unit_Price    Revenue    Profit
# ...

# %%
df.shape
# Out:
# (200000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Order_ID       200000 non-null  int64
#  1   Order_Date     200000 non-null  object
#  2   Customer_Name  200000 non-null  object
#  3   City           200000 non-null  object
#  4   State          200000 non-null  object
#  5   Region         200000 non-null  object
#  6   Country        200000 non-null  object
#  7   Category       200000 non-null  object
#  8   Sub_Category   200000 non-null  object
#  9   Product_Name   200000 non-null  object
#  10  Quantity       200000 non-null  int64
#  11   Unit_Price    200000 non-null  float64
#  12   Revenue       200000 non-null  float64
#  13   Profit        200000 non-null  float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 21.4+ MB

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Order_Date       0
# Customer_Name    0
# City             0
# State            0
# Region           0
# Country          0
# Category         0
# Sub_Category     0
# Product_Name     0
# Quantity         0
#  Unit_Price      0
#  Revenue         0
#  Profit          0
# dtype: int64

# %%
df[df.astype(str).apply(lambda x: x.str.strip() == '').any(axis =1)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_Name, City, State, Region, Country, Category, Sub_Category, Product_Name, Quantity,  Unit_Price ,  Revenue ,  Profit ]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#convert Order_date from text to datetime
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df.dtypes
# Out:
# Order_ID                  int64
# Order_Date       datetime64[ns]
# Customer_Name            object
# City                     object
# State                    object
# Region                   object
# Country                  object
# Category                 object
# Sub_Category             object
# Product_Name             object
# Quantity                  int64
#  Unit_Price             float64
#  Revenue                float64
#  Profit                 float64
# dtype: object

# %%
df.describe()
# Out:
#             Order_ID                  Order_Date       Quantity  \
# count  200000.000000                      200000  200000.000000
# mean   100000.500000  2024-02-11 17:22:01.632000       1.854000
# min         1.000000         2023-01-01 00:00:00       1.000000
# 25%     50000.750000         2023-09-12 00:00:00       1.000000
# 50%    100000.500000         2024-01-02 00:00:00       1.000000
# 75%    150000.250000         2024-09-13 00:00:00       2.000000
# max    200000.000000         2024-12-31 00:00:00      11.000000
# std     57735.171256                         NaN       1.100536
#
#          Unit_Price        Revenue         Profit
# count  200000.000000  200000.000000  200000.000000
# mean      382.855615     712.038725     157.743041
# min        17.030000      17.030000       3.920000
# 25%       162.760000     229.187500      59.210000
# 50%       303.545000     464.880000     109.530000
# 75%       562.252500     881.302500     199.402500
# ...

# %%
#Check the number of unique products, categories, and sub-categories
print("Products:", df['Product_Name'].nunique())
print("Categories:", df['Category'].nunique())
print("Sub-Categories:", df['Sub_Category'].nunique())
# Out:
# Products: 49
# Categories: 4
# Sub-Categories: 19

# %%
#Display the unique categories, sub-categories, and products
print("Categories:")
print(df['Category'].unique())

print("\nSub-Categories:")
print(df['Sub_Category'].unique())

print("\nProducts:")
print(df['Product_Name'].unique())
# Out:
# Categories:
# ['Accessories' 'Clothing & Apparel' 'Electronics' 'Home & Furniture']
#
# Sub-Categories:
# ['Small Electronics' 'Sportswear' 'Bags' 'Home Appliances' 'Wearables'
#  "Men's Wear" 'Footwear' 'Smartphones' "Women's Wear"
#  'Wearable Accessories' 'Tablets' 'Kids Wear' 'Storage' 'Bedding'
#  'TVs & Audio' 'Home Decor' 'Laptops' 'Kitchenware' 'Furniture']
#
# Products:
# ['Phone Case' 'Charging Cable' 'Nike Air Force 1' 'Adidas Tracksuit'
#  'Backpack' 'Instant Pot' 'Apple Watch' "Levi's Jeans" 'Timberland Boots'
#  'Apple iPhone 14' 'Old Navy Dress' 'Watch Strap' 'Samsung Galaxy Tab'
#  "Carter's Onesie" 'Storage Rack' 'GAP Hoodie' 'KitchenAid Mixer' 'Wallet'
#  'Power Bank' 'Samsung Galaxy S23' 'Tote Bag' 'Tempur-Pedic Mattress'
#  'LG OLED TV' 'Google Pixel 7' 'Throw Pillows' 'MacBook Air'
#  'Nike Running Shoes' 'Brooklinen Sheets' "Children's Hoodie" 'Belt'
#  'Under Armour T-Shirt' 'iPad Pro' 'Ashley Recliner' 'Zara Blouse'
# ...

# %%
#Export the cleaned dataset to CSV and download the file
df.to_csv('product_performance_cleaned.csv', index=False)

from google.colab import files
files.download('product_performance_cleaned.csv')
